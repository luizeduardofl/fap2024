# %%
class Televisao:
  def __init__(self):
    self.ligada = False
    self.canal = 4
    self.tamanho = 32
    self.marca = 'Samsung'

# %%
tv_quarto = Televisao()
tv_sala = Televisao()

tv_quarto.marca = 'Sony'
tv_quarto.tamanho = 42

tv_sala.marca = 'LG'
tv_sala.tamanho = 49

print(tv_quarto.marca, tv_quarto.tamanho)
print(tv_sala.marca, tv_sala.tamanho)
# Out:
# Sony 42
# LG 49

# %%
class Televisao:
  def __init__(self, min=2, max=14):
    self.ligada = False
    self.canal = 2
    self.cmin = min
    self.cmax = max
  def muda_canal_para_baixo(self):
    if (self.canal - 1 >= self.cmin):
      self.canal -= 1
    else:
      self.canal = self.cmax

  def muda_canal_para_cima(self):
    if (self.canal + 1 <= self.cmax):
      self.canal += 1
    else:
      self.canal = self.cmin

# %%
tv = Televisao()

tv_sala = Televisao(1, 10)
tv_quarto = Televisao()
